# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Future_jobs=pd.read_csv("future_jobs_dataset.csv")
Future_jobs
# Out:
#       job_id                   job_title           industry   location  \
# 0          1          Quantum Researcher  Quantum Computing  Singapore
# 1          2   Renewable Energy Engineer         Green Tech  Singapore
# 2          3          Quantum Researcher  Quantum Computing      Tokyo
# 3          4      Sustainability Analyst         Green Tech  Singapore
# 4          5     Smart Contract Engineer         Blockchain     London
# ...      ...                         ...                ...        ...
# 9995    9996      Sustainability Analyst         Green Tech   New York
# 9996    9997        Blockchain Developer         Blockchain   New York
# 9997    9998  Quantum Software Developer  Quantum Computing     Berlin
# 9998    9999   Renewable Energy Engineer         Green Tech   New York
# 9999   10000                 AI Engineer                 AI  Singapore
#
#       salary_usd                         skills_required remote_option  \
# ...

# %%
Future_jobs.isna().sum()
# Out:
# job_id             0
# job_title          0
# industry           0
# location           0
# salary_usd         0
# skills_required    0
# remote_option      0
# company_size       0
# posting_date       0
# dtype: int64

# %%
Future_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           10000 non-null  int64
#  1   job_title        10000 non-null  object
#  2   industry         10000 non-null  object
#  3   location         10000 non-null  object
#  4   salary_usd       10000 non-null  int64
#  5   skills_required  10000 non-null  object
#  6   remote_option    10000 non-null  object
#  7   company_size     10000 non-null  object
#  8   posting_date     10000 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 703.2+ KB

# %%
Future_jobs.head()
# Out:
#    job_id                  job_title           industry   location  \
# 0       1         Quantum Researcher  Quantum Computing  Singapore
# 1       2  Renewable Energy Engineer         Green Tech  Singapore
# 2       3         Quantum Researcher  Quantum Computing      Tokyo
# 3       4     Sustainability Analyst         Green Tech  Singapore
# 4       5    Smart Contract Engineer         Blockchain     London
#
#    salary_usd                         skills_required remote_option  \
# 0      175780      Linear Algebra, Quantum Algorithms            No
# 1      137481  Climate Data Analysis, Energy Modeling           Yes
# 2      182081                  Linear Algebra, Qiskit            No
# 3      113822  Climate Data Analysis, Energy Modeling            No
# 4       92575                          Rust, Solidity           Yes
#
#   company_size posting_date
# 0        Large   2025-07-22
# 1        Large   2025-09-26
# 2       Medium   2025-12-31
# 3        Large   2025-05-29
# ...

# %%
Future_jobs.nunique()
# Out:
# job_id             10000
# job_title              9
# industry               4
# location               6
# salary_usd          9738
# skills_required       20
# remote_option          2
# company_size           3
# posting_date         365
# dtype: int64

# %%
Future_jobs.shape
# Out:
# (10000, 9)

# %%
Future_jobs.dtypes
# Out:
# job_id              int64
# job_title          object
# industry           object
# location           object
# salary_usd          int64
# skills_required    object
# remote_option      object
# company_size       object
# posting_date       object
# dtype: object

# %%
Future_jobs.describe(include='all')
# Out:
#              job_id                   job_title           industry  location  \
# count   10000.00000                       10000              10000     10000
# unique          NaN                           9                  4         6
# top             NaN  Quantum Software Developer  Quantum Computing  New York
# freq            NaN                        1278               2519      1689
# mean     5000.50000                         NaN                NaN       NaN
# std      2886.89568                         NaN                NaN       NaN
# min         1.00000                         NaN                NaN       NaN
# 25%      2500.75000                         NaN                NaN       NaN
# 50%      5000.50000                         NaN                NaN       NaN
# 75%      7500.25000                         NaN                NaN       NaN
# max     10000.00000                         NaN                NaN       NaN
#
# ...

# %% [markdown]
# ## data processing

# %%
columns=Future_jobs.columns

# %%
for col in columns:
    plt.figure()
    sns.boxplot(Future_jobs[col])
    plt.title(f" {col}")
    plt.show()

# %%
Future_jobs=Future_jobs.drop(Future_jobs.columns[0],axis=1)
Future_jobs.head(5)
# Out:
#                    job_title           industry   location  salary_usd  \
# 0         Quantum Researcher  Quantum Computing  Singapore      175780
# 1  Renewable Energy Engineer         Green Tech  Singapore      137481
# 2         Quantum Researcher  Quantum Computing      Tokyo      182081
# 3     Sustainability Analyst         Green Tech  Singapore      113822
# 4    Smart Contract Engineer         Blockchain     London       92575
#
#                           skills_required remote_option company_size  \
# 0      Linear Algebra, Quantum Algorithms            No        Large
# 1  Climate Data Analysis, Energy Modeling           Yes        Large
# 2                  Linear Algebra, Qiskit            No       Medium
# 3  Climate Data Analysis, Energy Modeling            No        Large
# 4                          Rust, Solidity           Yes        Small
#
#   posting_date
# 0   2025-07-22
# 1   2025-09-26
# 2   2025-12-31
# 3   2025-05-29
# 4   2025-03-30

# %% [markdown]
# ## EDA

# %%
Future_jobs["posting_date"]=pd.to_datetime(Future_jobs["posting_date"])

# %%
Future_jobs.dtypes
# Out:
# job_id                      int64
# job_title                  object
# industry                   object
# location                   object
# salary_usd                  int64
# skills_required            object
# remote_option              object
# company_size               object
# posting_date       datetime64[ns]
# dtype: object

# %%
Future_jobs.groupby('industry')['salary_usd'].mean()
# Out:
# industry
# AI                   150672.369181
# Blockchain           149383.765106
# Green Tech           149329.900000
# Quantum Computing    151130.696308
# Name: salary_usd, dtype: float64
