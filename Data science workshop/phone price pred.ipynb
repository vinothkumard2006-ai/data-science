# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("cleaned_data.csv")
data.head().T
# Out:
#                                        0                          1  \
# model                      oneplus 11 5g  oneplus nord ce 2 lite 5g
# price                              54999                      19989
# rating                              89.0                       81.0
# os                           Android v13                Android v12
# sim_type                            Dual                       Dual
# network_type                          5g                         5g
# VoLTE                               True                       True
# NFC                                 True                      False
# ir_blaster                         False                      False
# chipset                Snapdragon 8 Gen2             Snapdragon 695
# core_type                      Octa Core                  Octa Core
# clock_ghz                            3.2                        2.2
# ram_gb                                12                          6
# storage_gb                            12                          6
# battery_mah                       5000.0                     5000.0
# fast_charge_w                      100.0                       33.0
# screen_size_in                       6.7                       6.59
# resolution                     1440x3216                  1080x2412
# refresh_rate_hz                    120.0                      120.0
# display_type                  Punch Hole                 Punch Hole
# rear_camera_mp_list         [50, 48, 32]                 [64, 2, 2]
# rear_camera_count                      3                          3
# rear_camera_max_mp                  50.0                       64.0
# front_camera_mp                     16.0                       16.0
# memory_card_supported                  1                          1
# memory_card_type                     NaN                     Hybrid
# memory_card_max_gb                   NaN                     1024.0
#
#                                            2                     3  \
# model                  samsung galaxy a14 5g  motorola moto g62 5g
# price                                  16499                 14999
# rating                                  75.0                  81.0
# os                               Android v13           Android v12
# sim_type                                Dual                  Dual
# network_type                              5g                    5g
# VoLTE                                   True                  True
# NFC                                    False                 False
# ir_blaster                             False                 False
# chipset                          Exynos 1330       Snapdragon  695
# core_type                          Octa Core             Octa Core
# clock_ghz                                2.4                   2.2
# ram_gb                                     4                     6
# storage_gb                                 4                     6
# battery_mah                           5000.0                5000.0
# fast_charge_w                           15.0                   NaN
# screen_size_in                           6.6                  6.55
# resolution                         1080x2408             1080x2400
# refresh_rate_hz                         90.0                 120.0
# display_type                Water Drop Notch            Punch Hole
# rear_camera_mp_list               [50, 2, 2]            [50, 8, 2]
# rear_camera_count                          3                     3
# rear_camera_max_mp                      50.0                  50.0
# front_camera_mp                         13.0                  16.0
# memory_card_supported                      1                     1
# memory_card_type                   Dedicated                Hybrid
# memory_card_max_gb                    1024.0                1024.0
#
#                                         4
# model                  realme 10 pro plus
# price                               24999
# rating                               82.0
# os                            Android v13
# sim_type                             Dual
# network_type                           5g
# VoLTE                                True
# NFC                                 False
# ir_blaster                          False
# chipset                    Dimensity 1080
# core_type                       Octa Core
# clock_ghz                             2.6
# ram_gb                                  6
# storage_gb                              6
# battery_mah                        5000.0
# fast_charge_w                        67.0
# screen_size_in                        6.7
# resolution                      1080x2412
# refresh_rate_hz                     120.0
# display_type                   Punch Hole
# rear_camera_mp_list           [108, 8, 2]
# rear_camera_count                       3
# rear_camera_max_mp                  108.0
# front_camera_mp                      16.0
# memory_card_supported                   1
# memory_card_type                      NaN
# memory_card_max_gb                    NaN

# %%
data.isna().sum()
# Out:
# model                      0
# price                      0
# rating                     0
# os                        26
# sim_type                   0
# network_type               0
# VoLTE                      0
# NFC                        0
# ir_blaster                 0
# chipset                    0
# core_type                  6
# clock_ghz                 41
# ram_gb                     0
# storage_gb                 0
# battery_mah               11
# fast_charge_w            204
# screen_size_in             1
# resolution                 1
# refresh_rate_hz          360
# display_type              85
# rear_camera_mp_list        0
# rear_camera_count          0
# rear_camera_max_mp        16
# front_camera_mp           25
# memory_card_supported      0
# memory_card_type         127
# memory_card_max_gb       468
# dtype: int64

# %%
data.dtypes
# Out:
# model                     object
# price                      int64
# rating                   float64
# os                        object
# sim_type                  object
# network_type              object
# VoLTE                       bool
# NFC                         bool
# ir_blaster                  bool
# chipset                   object
# core_type                 object
# clock_ghz                float64
# ram_gb                     int64
# storage_gb                 int64
# battery_mah              float64
# fast_charge_w            float64
# screen_size_in           float64
# resolution                object
# refresh_rate_hz          float64
# display_type              object
# rear_camera_mp_list       object
# rear_camera_count          int64
# rear_camera_max_mp       float64
# front_camera_mp          float64
# memory_card_supported      int64
# memory_card_type          object
# memory_card_max_gb       float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968 entries, 0 to 967
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model                  968 non-null    object
#  1   price                  968 non-null    int64
#  2   rating                 968 non-null    float64
#  3   os                     942 non-null    object
#  4   sim_type               968 non-null    object
#  5   network_type           968 non-null    object
#  6   VoLTE                  968 non-null    bool
#  7   NFC                    968 non-null    bool
#  8   ir_blaster             968 non-null    bool
#  9   chipset                968 non-null    object
#  10  core_type              962 non-null    object
#  11  clock_ghz              927 non-null    float64
#  12  ram_gb                 968 non-null    int64
#  13  storage_gb             968 non-null    int64
#  14  battery_mah            957 non-null    float64
#  15  fast_charge_w          764 non-null    float64
#  16  screen_size_in         967 non-null    float64
#  17  resolution             967 non-null    object
#  18  refresh_rate_hz        608 non-null    float64
#  19  display_type           883 non-null    object
#  20  rear_camera_mp_list    968 non-null    object
#  21  rear_camera_count      968 non-null    int64
#  22  rear_camera_max_mp     952 non-null    float64
#  23  front_camera_mp        943 non-null    float64
#  24  memory_card_supported  968 non-null    int64
#  25  memory_card_type       841 non-null    object
#  26  memory_card_max_gb     500 non-null    float64
# dtypes: bool(3), float64(9), int64(5), object(10)
# memory usage: 184.5+ KB

# %%
columns=data.columns

# %%
columns
# Out:
# Index(['model', 'price', 'rating', 'os', 'sim_type', 'network_type', 'VoLTE',
#        'NFC', 'ir_blaster', 'chipset', 'core_type', 'clock_ghz', 'ram_gb',
#        'storage_gb', 'battery_mah', 'fast_charge_w', 'screen_size_in',
#        'resolution', 'refresh_rate_hz', 'display_type', 'rear_camera_mp_list',
#        'rear_camera_count', 'rear_camera_max_mp', 'front_camera_mp',
#        'memory_card_supported', 'memory_card_type', 'memory_card_max_gb'],
#       dtype='object')

# %%
cat_cols = data.select_dtypes(include="object").columns
for col in cat_cols:
     print(col)
     print(data[col].nunique())
# Out:
# model
# 777
# os
# 35
# sim_type
# 2
# network_type
# 2
# chipset
# 240
# core_type
# 4
# resolution
# 84
# display_type
# 5
# rear_camera_mp_list
# 146
# memory_card_type
# 2
